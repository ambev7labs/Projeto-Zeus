# %%
# !pip install keras
# !pip install sklearn
# !pip install livelossplot
# Out:
# Requirement already satisfied: keras in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (2.4.3)
# Requirement already satisfied: h5py in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from keras) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from keras) (1.19.2)
# Requirement already satisfied: pyyaml in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from keras) (5.3.1)
# Requirement already satisfied: scipy>=0.14 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from keras) (1.5.4)
# Requirement already satisfied: six in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from h5py->keras) (1.15.0)
# Requirement already satisfied: sklearn in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from sklearn) (0.23.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from scikit-learn->sklearn) (0.17.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from scikit-learn->sklearn) (1.5.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from scikit-learn->sklearn) (1.19.2)
# Requirement already satisfied: livelossplot in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (0.5.3)
# Requirement already satisfied: bokeh in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from livelossplot) (2.2.3)
# Requirement already satisfied: ipython in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from livelossplot) (7.19.0)
# Requirement already satisfied: matplotlib in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from livelossplot) (3.3.3)
# Requirement already satisfied: tornado>=5.1 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from bokeh->livelossplot) (6.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from bokeh->livelossplot) (3.7.4.3)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from bokeh->livelossplot) (5.3.1)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from bokeh->livelossplot) (8.1.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from bokeh->livelossplot) (2.8.1)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from bokeh->livelossplot) (1.19.2)
# Requirement already satisfied: packaging>=16.8 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from bokeh->livelossplot) (20.8)
# Requirement already satisfied: Jinja2>=2.7 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from bokeh->livelossplot) (2.11.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from Jinja2>=2.7->bokeh->livelossplot) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from packaging>=16.8->bokeh->livelossplot) (2.4.7)
# Requirement already satisfied: six>=1.5 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from python-dateutil>=2.1->bokeh->livelossplot) (1.15.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from ipython->livelossplot) (5.0.5)
# Requirement already satisfied: pygments in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from ipython->livelossplot) (2.7.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from ipython->livelossplot) (3.0.8)
# Requirement already satisfied: decorator in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from ipython->livelossplot) (4.4.2)
# Requirement already satisfied: pickleshare in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from ipython->livelossplot) (0.7.5)
# Requirement already satisfied: colorama in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from ipython->livelossplot) (0.4.4)
# Requirement already satisfied: backcall in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from ipython->livelossplot) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from ipython->livelossplot) (51.1.2.post20210112)
# Requirement already satisfied: jedi>=0.10 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from ipython->livelossplot) (0.17.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from jedi>=0.10->ipython->livelossplot) (0.7.1)
# Requirement already satisfied: wcwidth in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->livelossplot) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from traitlets>=4.2->ipython->livelossplot) (0.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from matplotlib->livelossplot) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\cliente\.conda\envs\tensorflow\lib\site-packages (from matplotlib->livelossplot) (0.10.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import livelossplot
import pickle

# %%
plot_losses = livelossplot.PlotLossesKeras()
Files_Folder = 'Dados/'
Files_path_MA = Files_Folder + "MA/"
Files_path_EE = Files_Folder + "EE/"
path = Files_path_MA + 'DataBase_MA.xlsx'
dados = pd.read_excel(path, engine = "openpyxl")
dados = dados.sort_values("Dia", ascending=True)

# %% [markdown]
# # Define critério de limpeza da variável de controle
# primeiroQuartil = np.percentile(dados["PRINCIPAL (kW)"].values, 25)
# terceiroQuartil = np.percentile(dados["PRINCIPAL (kW)"].values, 75)
# passo = 1.5 * (terceiroQuartil - primeiroQuartil)
#
# df = []
# for i in range(0, len(dados)):
#     consumo = dados["PRINCIPAL (kW)"].values[i]
#     if consumo > primeiroQuartil - passo and consumo < terceiroQuartil + passo:
#         df.append(dados.values[i])
#
# dados = pd.DataFrame(df, columns=dados.columns)

# %%
# Faz a limpeza das variáveis de entrada
entrada = dados.drop(columns=["PRINCIPAL (kW)","Consumo de Água", "Dia"]).values
remove = IsolationForest(random_state=0).fit(entrada)
out = remove.predict(entrada)

df = []
for i in range(0, len(out)):
    if out[i] == 1:
        df.append(dados.values[i])
        
dados = pd.DataFrame(df, columns=dados.columns)

# %% [markdown]
# '''# Insere a informação de sazonalidade
# sazon = []
# for i in range(0, len(dados)):
#     ts = pd.Timestamp(dados["Dia"].values[i])
#     sazon.append(ts.month)
#
# dados["Sazonalidade"] = sazon'''

# %%
# Separa o dataframe de teste e de treino
volumeTreino = 0.9
iCorte = int(len(dados) * volumeTreino)
dfTreino = dados.loc[:iCorte, :]
dfTeste = dados.loc[iCorte:, :]

# Separa variáveis dependentes e independentes
xTreino = dfTreino.drop(columns=["PRINCIPAL (kW)","Consumo de Água", "Dia",'563 (964)']).values
yTreino = dfTreino["Consumo de Água"].values

xTeste = dfTeste.drop(columns=["PRINCIPAL (kW)","Consumo de Água", "Dia",'563 (964)']).values
yTeste = dfTeste["Consumo de Água"].values

# Executa a padronização
sc = StandardScaler()
xTreino = sc.fit_transform(xTreino)
xTeste = sc.transform(xTeste)

# %%
# Cria a rede neural
ann = Sequential()
ann.add(Dense(10, activation="relu"))
ann.add(Dense(50, activation="relu"))
ann.add(Dense(100, activation="relu"))
ann.add(Dense(50, activation="relu"))
ann.add(Dense(10, activation="relu"))
ann.add(Dense(1, activation="linear"))
    
# Compila e treina
ann.compile(optimizer="RMSprop", loss="mean_squared_error")
hist = ann.fit(xTreino, yTreino, batch_size=32, epochs=300, verbose=0,callbacks=[plot_losses])
#finalLoss = hist.history["loss"][-1]
# Out:
# Loss
# 	loss             	 (min: 1501742.750, max: 47947144.000, cur: 1508187.500)

# %%
finalLoss = hist.history["loss"][-1]

# %%
# Faz a predição para o conjunto de teste
yPred = ann.predict(xTeste).reshape(1, -1)[0]
residuos = []
for i in range(0, len(yPred)):
    if yTeste[i] == 0:
        continue
        
    residuos.append((abs(yPred[i] - yTeste[i]) / yTeste[i]))

# %%
# Cria as listas para visualização
plotTreino = np.array([i for i in range(0, len(yTreino))])
plotTeste = np.array([i for i in range(len(yTreino), len(yTreino) + len(yTeste))])

plt.figure(figsize=(25, 8))
#plt.plot(plotTreino, yTreino, label="Treino", color="black")
plt.plot(plotTeste, yTeste, label="Real", color="blue")
plt.plot(plotTeste, yPred, label="Previsto", color="red")
plt.legend()
plt.show()

# %% [markdown]
# Código para importar dados que queremos usar para fazer predições e salvar um arquivo com as predições realizadas

# %%
dados_pred = pd.read_excel(Files_path_MA + "DadosPredicao_MA.xlsx", engine = "openpyxl")
dados_pred = dados_pred.sort_values("Dia", ascending=True)

xPred = dados_pred.drop(columns=["PRINCIPAL (kW)", "Consumo de Água", "Dia", '563 (964)']).values

# Executa a padronização
xPred = sc.transform(xPred)

# %% [markdown]
# Prediz os valores e salva o arquivo

# %%
yPred = ann.predict(xPred).reshape(1, -1)[0]
dados_pred['Prediction'] = yPred
dados_pred.to_excel(Files_Folder + 'Output_MA.xlsx', index = False)

# %% [markdown]
# Salva o modelo e os pesos do mesmo na pasta Modelo.

# %%
# serialize model to JSON
model_path = "Modelo/"
model_json = ann.to_json()
with open(model_path + "model_MA.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
ann.save_weights(model_path + "model_MA.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# Carrega o modelo Criado e utiliza para predição

# %%
# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
 
# evaluate loaded model on test data
loaded_model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
score = loaded_model.evaluate(X, Y, verbose=0)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-1c1e9ca45d30> in <module>
#       1 # load json and create model
# ----> 2 json_file = open('model.json', 'r')
#       3 loaded_model_json = json_file.read()
#       4 json_file.close()
#       5 loaded_model = model_from_json(loaded_model_json)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model.json'
